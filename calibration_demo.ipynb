# %%
push!(LOAD_PATH, ".");

# %%
include("run_sim.jl");

# %%
include("calibration.jl");

# %%
include("calibration_abcdez.jl");

# %%
# short calibration for testing purposes
res = calibration_abcde!(EmpiricalParams(), nparticles=100, nsims_max=1000);
# Out:
# ┌ Info: Running abcdesmc! with executor (1 threads available)
# └   typeof(ex) = Transducers.ThreadedEx{@NamedTuple{}}
# ┌ Info: Running abcdesmc! with
# │   ϵ_target = 0.1
# │   nparticles = 100
# │   α = 0.95
# │   δess = 0.5
# │   nsims_max = 1000
# │   Kmcmc = 3
# │   Kmcmc_min = 1.0
# │   ABCk = ABCdeZ.Indicator0toϵ
# │   facc_min = 0.15
# │   facc_tune = 0.975
# │   rng = Random._GLOBAL_RNG()
# │   parallel = true
# └   verboseout = true
# ┌ Info: Finished run:
# │   iteration = 1
# │   nsim = 31
# │   ϵ = 16.059542559090563
# │   range_ϵ = (1.2086414212785352, 67.79795923829928)
# │   ess = 94.99999999999999
# │   facc = 0.0912280701754386
# └   logZ = -0.05129329438755058
# ┌ Info: Finished run:
# │   iteration = 2
# │   nsim = 55
# │   ϵ = 7.166521946331918
# │   range_ϵ = (1.2086414212785352, 67.79795923829928)
# │   ess = 90.00000000000001
# │   facc = 0.08148148148148149
# └   logZ = -0.10536051565782606
# ┌ Info: Finished run:
# │   iteration = 3
# │   nsim = 92
# ...

# %%
present_solution_abcde!(res)
# Out:
# Standardabweichungen der Parameter:
# prev: 2.7784449620288307
# rate parents: 2.931100370422776
# rate friends: 2.8082484926120284
# rate friends healthy: 2.8351689075823874
# rate ac: 2.8952503229430078
# rate child: 2.4855178603380477
# rate spouse: 2.8019814623856876
# rate spouse healthy: 2.6075066240192215
# homophily friends: 0.29169105007036783
# homophily spouse: 0.2859520052983047
# homophily ac: 0.28278838320772337
# lambda: 0.2822544015046626
# scaling: 1.1176981206723877
# w_mean: 0.24659801371346068
# h expo: 0.2878068662508512
#
# Mittelwerte der Kalibrierungsergebnisse:
# prev (12 months): 0.012655555774940914 Standardabweichung: 0.031774284670441244
# risk of depression between 15 and 65: 0.18824794085944022 Standardabweichung: 0.33899156616871307
#
# risk for another episode, if person has at least one depressive episode: 0.9085362021944576 Standardabweichung: 0.1544943513844324
# ...
